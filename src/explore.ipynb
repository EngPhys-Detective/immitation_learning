# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
# Out:
# 2023-11-26 20:11:30.951923: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-26 20:11:30.955108: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/fizzer/.local/lib/python3.8/site-packages/cv2/../../lib64:/opt/ros/noetic/lib
# 2023-11-26 20:11:30.955119: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path = '/home/fizzer/enph_ws/src/immitation_learning/data'
target = '/home/fizzer/enph_ws/src/immitation_learning/processed_data'

# %%
img = cv2.imread(path + '/forward/1_1022.png')
print(img.shape)
plt.imshow(img[220:720,:,:])
print(type(img) == np.ndarray)
# Out:
# [ WARN:0@5.350] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/fizzer/enph_ws/src/immitation_learning/data/forward/1_1022.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> img = cv2.imread(path + '/forward/1_1022.png')
# ----> <a href='vscode-notebook-cell:/home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> print(img.shape)
#       <a href='vscode-notebook-cell:/home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(img[220:720,:,:])
# ...

# %%
for dir in os.listdir(path):
    for file in os.listdir(path + '/' + dir):
        img = cv2.imread(path + '/' + dir + '/' + file)
        if file.find('_') == -1:
            cv2.imwrite(os.path.join(target,dir,'2_' + file), img[220:720,:,:])
        else:
            cv2.imwrite(os.path.join(target,dir,file), img[220:720,:,:])
# Out:
# libpng error: Read Error
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb Cell 4 line 7
#       <a href='vscode-notebook-cell:/home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     cv2.imwrite(os.path.join(target,dir,'2_' + file), img[220:720,:,:])
#       <a href='vscode-notebook-cell:/home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> else:
# ----> <a href='vscode-notebook-cell:/home/fizzer/enph_ws/src/immitation_learning/src/explore.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>     cv2.imwrite(os.path.join(target,dir,file), img[220:720,:,:])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
s = "exec"
print(s.find('_'))
# Out:
# -1

# %%
path = '/home/fizzer/enph_ws/src/immitation_learning/data/dirt_track'
for dir in os.listdir(path):
    for file in os.listdir(path + '/' + dir):
        try:
            if type(cv2.imread(path + '/' + dir + '/' + file)) != np.ndarray or cv2.imread(path + '/' + dir + '/' + file).shape != (72, 128, 3):
                print(path + '/' + dir + '/' + file)
        except:
            print(path + '/' + dir + '/' + file)

# %%
# Define the path to the model file
models_path = '/home/fizzer/enph_ws/src/immitation_learning/models' 


# Load the CNN model
# model = tf.keras.models.load_model(models_path + '/cnn1.h5')

# Define the path to the test image
test_image_path = '/home/fizzer/enph_ws/src/immitation_learning/data/paved_track/forward/1_2.png'

# Read the test image
test_image = cv2.imread(test_image_path)
# Preprocess the test image (if required)
# resize the image to 72x128 pixels
plt.imshow(test_image)
print(test_image.shape)

# # Perform prediction on the test image
# prediction = model.predict(np.expand_dims(test_image, axis=0))
# print(prediction)
# test_image = cv2.resize(test_image, (128, 72))


# Print the predicted class or do further processing
# ...
# Out:
# (72, 128, 3)
